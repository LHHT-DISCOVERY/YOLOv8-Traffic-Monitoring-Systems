# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/YOLO_V8
# Out:
# /content/drive/MyDrive/YOLO_V8

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.1/78.2 GB disk)

# %% [markdown]
# # Mục mới

# %%
# !yolo predict model=/content/drive/MyDrive/YOLO_V8/runs/detect/train29/weights/best.pt source='/content/drive/MyDrive/YOLO_V8/test12.mp4'
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# video 1/1 (1/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 53.4ms
# video 1/1 (2/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 8.3ms
# video 1/1 (3/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 5.7ms
# video 1/1 (4/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 5.8ms
# video 1/1 (5/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (6/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 5.8ms
# video 1/1 (7/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 5.9ms
# video 1/1 (8/3726) /content/drive/MyDrive/YOLO_V8/test12.mp4: 384x640 (no detections), 6.0ms
# ...

# %%
# !rm -r /content/drive/MyDrive/YOLO_V8/coco128.yaml

# %%
# !cp -r /content/coco128_1 /content/drive/MyDrive/YOLO_V8

# %%
# !unzip -q /content/drive/MyDrive/YOLO_V8/coco128.zip

# %%
# !yolo train model=/content/drive/MyDrive/YOLO_V8/yolov8n.pt data=/content/drive/MyDrive/YOLO_V8/coco128.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
